# %%
import sklearn
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets import fetch_20newsgroups
from IPython.display import clear_output

# %%
newsgroups = fetch_20newsgroups(subset='all',remove = ('headers', 'footers', 'quotes'))
data = pd.DataFrame()
data['text'] = newsgroups.data
data['target'] = newsgroups.target
target_names = newsgroups.target_names

data
# Out:
#                                                     text  target
# 0      \n\nI am sure some bashers of Pens fans are pr...      10
# 1      My brother is in the market for a high-perform...       3
# 2      \n\n\n\n\tFinally you said what you dream abou...      17
# 3      \nThink!\n\nIt's the SCSI card doing the DMA t...       3
# 4      1)    I have an old Jasmine drive which I cann...       4
# 5      \n\nBack in high school I worked as a lab assi...      12
# 6      \n\nAE is in Dallas...try 214/241-6060 or 214/...       4
# 7      \n[stuff deleted]\n\nOk, here's the solution t...      10
# 8      \n\n\nYeah, it's the second one.  And I believ...      10
# 9      \nIf a Christian means someone who believes in...      19
# 10     the blood of the lamb.\n\nThis will be a hard ...      19
# 11      >say they have a "history of untrustworthy be...      11
# 12     930418\n\nDo what thou wilt shall be the whole...      19
# 13      How about Kirlian imaging ? I believe the FAQ...      13
# 14     \n\n\tThere is no notion of heliocentric, or e...       0
# 15     In the following report: _Turkey Eyes Regional...      17
# 16     Many thanks to those who replied to my appeal ...      12
# 17     .........\nI, some years ago, almost became a ...      12
# 18     \nThe Supreme Court seems to disagree with you...      11
# 19     \ned>1.  All of us that argue about gyroscopes...       8
# 20     : \n: I am considering buying a 1993 Chevy or ...       7
# 21     \nSorry, that's a feature.  The ICCCM specifie...       5
# 22     I don't have nor Imagine nor Real 3d, but as o...       1
# 23     \nI've only ever done it in an automatic. I wa...       8
# 24     I don't know the exact coverage in the states....      10
# 25     AW&ST  had a brief blurb on a Manned Lunar Exp...      14
# 26     \n\nThis was reported in Canadian papers Thurs...      16
# 27     Using the VMODE command, all you need to do is...       1
# 28     CAD Setup For Sale:\n\nG486PLB Local Bus Mothe...       6
# 29     [ . . .]\n\nI am a relativist who would like t...       0
# ...                                                  ...     ...
# 18816  \n\nHow about:\n\n\tThe Holocaust\n\tThe Spani...      15
# 18817  \nWhatever happened to uwm? Is it still availa...       5
# 18818  \n\n\nI'm sure there are many people who work ...       0
# 18819  \nYou'd have to purify the river water first. ...      13
# 18820  A new alternative to Scouting for those "unacc...       0
# 18821  {rest deleted}\n\nCan the Father possibly not ...      15
# 18822  \n\nThe lengthy article you quote doesn't impl...      17
# 18823  I have the local bus card also, and don't have...       2
# 18824  \nYou have to do the same sorts of things that...       5
# 18825  \n\n\n\n\tI think the Manta is the European na...       7
# 18826  \n\n\n\n    Apple has really confused people w...       4
# 18827  On 21 Apr 93 00:07:20 GMT, Theodore A. Kaldis ...      18
# 18828   \n \n Well, I'm a Wings fan and I think the F...      10
# 18829  I never thought I'd contribute to a Gateway th...       3
# 18830                              \n\n\n\n\n   Anaheim.       9
# 18831  Hello,\n\n    I am having a small problem with...       3
# 18832  \nI am asking you to believe in things not vis...      15
# 18833  I have an Alesis HR-16 drum machine for sale. ...       6
# 18834  \nProbably keep quiet and take it, lest they g...      11
# 18835  \nThey've been out of busines for years.\n\n\n...      12
# 18836  \n\nThere were a great many Germans, Poles and...      17
# 18837  \nAnd won't they have to change their name to ...      10
# 18838     [snip]\n   In the first place the death of ...      17
# 18839  \n[bible verses ag./ used ag. homosexuality de...      15
# 18840  Hi to all.\n\nSince all of you could also be a...       6
# 18841  DN> From: nyeda@cnsvax.uwec.edu (David Nye)\nD...      13
# 18842  \nNot in isolated ground recepticles (usually ...      12
# 18843  I just installed a DX2-66 CPU in a clone mothe...       3
# 18844  \nWouldn't this require a hyper-sphere.  In 3-...       1
# 18845  After a tip from Gary Crum (crum@fcom.cc.utah....       7
#
# [18846 rows x 2 columns]

# %% [markdown]
# # Intro to sklearn and classification
#
# ## Data Cleaning and Feature Creation

# %%
#Making all text lowercase
data['cleaned'] = data['text'].str.lower() 
data
# Out:
#                                                     text  target  \
# 0      \n\nI am sure some bashers of Pens fans are pr...      10
# 1      My brother is in the market for a high-perform...       3
# 2      \n\n\n\n\tFinally you said what you dream abou...      17
# 3      \nThink!\n\nIt's the SCSI card doing the DMA t...       3
# 4      1)    I have an old Jasmine drive which I cann...       4
# 5      \n\nBack in high school I worked as a lab assi...      12
# 6      \n\nAE is in Dallas...try 214/241-6060 or 214/...       4
# 7      \n[stuff deleted]\n\nOk, here's the solution t...      10
# 8      \n\n\nYeah, it's the second one.  And I believ...      10
# 9      \nIf a Christian means someone who believes in...      19
# 10     the blood of the lamb.\n\nThis will be a hard ...      19
# 11      >say they have a "history of untrustworthy be...      11
# 12     930418\n\nDo what thou wilt shall be the whole...      19
# 13      How about Kirlian imaging ? I believe the FAQ...      13
# 14     \n\n\tThere is no notion of heliocentric, or e...       0
# 15     In the following report: _Turkey Eyes Regional...      17
# 16     Many thanks to those who replied to my appeal ...      12
# 17     .........\nI, some years ago, almost became a ...      12
# 18     \nThe Supreme Court seems to disagree with you...      11
# 19     \ned>1.  All of us that argue about gyroscopes...       8
# 20     : \n: I am considering buying a 1993 Chevy or ...       7
# 21     \nSorry, that's a feature.  The ICCCM specifie...       5
# 22     I don't have nor Imagine nor Real 3d, but as o...       1
# 23     \nI've only ever done it in an automatic. I wa...       8
# 24     I don't know the exact coverage in the states....      10
# 25     AW&ST  had a brief blurb on a Manned Lunar Exp...      14
# 26     \n\nThis was reported in Canadian papers Thurs...      16
# 27     Using the VMODE command, all you need to do is...       1
# 28     CAD Setup For Sale:\n\nG486PLB Local Bus Mothe...       6
# 29     [ . . .]\n\nI am a relativist who would like t...       0
# ...                                                  ...     ...
# 18816  \n\nHow about:\n\n\tThe Holocaust\n\tThe Spani...      15
# 18817  \nWhatever happened to uwm? Is it still availa...       5
# 18818  \n\n\nI'm sure there are many people who work ...       0
# 18819  \nYou'd have to purify the river water first. ...      13
# 18820  A new alternative to Scouting for those "unacc...       0
# 18821  {rest deleted}\n\nCan the Father possibly not ...      15
# 18822  \n\nThe lengthy article you quote doesn't impl...      17
# 18823  I have the local bus card also, and don't have...       2
# 18824  \nYou have to do the same sorts of things that...       5
# 18825  \n\n\n\n\tI think the Manta is the European na...       7
# 18826  \n\n\n\n    Apple has really confused people w...       4
# 18827  On 21 Apr 93 00:07:20 GMT, Theodore A. Kaldis ...      18
# 18828   \n \n Well, I'm a Wings fan and I think the F...      10
# 18829  I never thought I'd contribute to a Gateway th...       3
# 18830                              \n\n\n\n\n   Anaheim.       9
# 18831  Hello,\n\n    I am having a small problem with...       3
# 18832  \nI am asking you to believe in things not vis...      15
# 18833  I have an Alesis HR-16 drum machine for sale. ...       6
# 18834  \nProbably keep quiet and take it, lest they g...      11
# 18835  \nThey've been out of busines for years.\n\n\n...      12
# 18836  \n\nThere were a great many Germans, Poles and...      17
# 18837  \nAnd won't they have to change their name to ...      10
# 18838     [snip]\n   In the first place the death of ...      17
# 18839  \n[bible verses ag./ used ag. homosexuality de...      15
# 18840  Hi to all.\n\nSince all of you could also be a...       6
# 18841  DN> From: nyeda@cnsvax.uwec.edu (David Nye)\nD...      13
# 18842  \nNot in isolated ground recepticles (usually ...      12
# 18843  I just installed a DX2-66 CPU in a clone mothe...       3
# 18844  \nWouldn't this require a hyper-sphere.  In 3-...       1
# 18845  After a tip from Gary Crum (crum@fcom.cc.utah....       7
#
#                                                  cleaned
# 0      \n\ni am sure some bashers of pens fans are pr...
# 1      my brother is in the market for a high-perform...
# 2      \n\n\n\n\tfinally you said what you dream abou...
# 3      \nthink!\n\nit's the scsi card doing the dma t...
# 4      1)    i have an old jasmine drive which i cann...
# 5      \n\nback in high school i worked as a lab assi...
# 6      \n\nae is in dallas...try 214/241-6060 or 214/...
# 7      \n[stuff deleted]\n\nok, here's the solution t...
# 8      \n\n\nyeah, it's the second one.  and i believ...
# 9      \nif a christian means someone who believes in...
# 10     the blood of the lamb.\n\nthis will be a hard ...
# 11      >say they have a "history of untrustworthy be...
# 12     930418\n\ndo what thou wilt shall be the whole...
# 13      how about kirlian imaging ? i believe the faq...
# 14     \n\n\tthere is no notion of heliocentric, or e...
# 15     in the following report: _turkey eyes regional...
# 16     many thanks to those who replied to my appeal ...
# 17     .........\ni, some years ago, almost became a ...
# 18     \nthe supreme court seems to disagree with you...
# 19     \ned>1.  all of us that argue about gyroscopes...
# 20     : \n: i am considering buying a 1993 chevy or ...
# 21     \nsorry, that's a feature.  the icccm specifie...
# 22     i don't have nor imagine nor real 3d, but as o...
# 23     \ni've only ever done it in an automatic. i wa...
# 24     i don't know the exact coverage in the states....
# 25     aw&st  had a brief blurb on a manned lunar exp...
# 26     \n\nthis was reported in canadian papers thurs...
# 27     using the vmode command, all you need to do is...
# 28     cad setup for sale:\n\ng486plb local bus mothe...
# 29     [ . . .]\n\ni am a relativist who would like t...
# ...                                                  ...
# 18816  \n\nhow about:\n\n\tthe holocaust\n\tthe spani...
# 18817  \nwhatever happened to uwm? is it still availa...
# 18818  \n\n\ni'm sure there are many people who work ...
# 18819  \nyou'd have to purify the river water first. ...
# 18820  a new alternative to scouting for those "unacc...
# 18821  {rest deleted}\n\ncan the father possibly not ...
# 18822  \n\nthe lengthy article you quote doesn't impl...
# 18823  i have the local bus card also, and don't have...
# 18824  \nyou have to do the same sorts of things that...
# 18825  \n\n\n\n\ti think the manta is the european na...
# 18826  \n\n\n\n    apple has really confused people w...
# 18827  on 21 apr 93 00:07:20 gmt, theodore a. kaldis ...
# 18828   \n \n well, i'm a wings fan and i think the f...
# 18829  i never thought i'd contribute to a gateway th...
# 18830                              \n\n\n\n\n   anaheim.
# 18831  hello,\n\n    i am having a small problem with...
# 18832  \ni am asking you to believe in things not vis...
# 18833  i have an alesis hr-16 drum machine for sale. ...
# 18834  \nprobably keep quiet and take it, lest they g...
# 18835  \nthey've been out of busines for years.\n\n\n...
# 18836  \n\nthere were a great many germans, poles and...
# 18837  \nand won't they have to change their name to ...
# 18838     [snip]\n   in the first place the death of ...
# 18839  \n[bible verses ag./ used ag. homosexuality de...
# 18840  hi to all.\n\nsince all of you could also be a...
# 18841  dn> from: nyeda@cnsvax.uwec.edu (david nye)\nd...
# 18842  \nnot in isolated ground recepticles (usually ...
# 18843  i just installed a dx2-66 cpu in a clone mothe...
# 18844  \nwouldn't this require a hyper-sphere.  in 3-...
# 18845  after a tip from gary crum (crum@fcom.cc.utah....
#
# [18846 rows x 3 columns]

# %%
import re
#Removing special characters
data['cleaned'] = data['cleaned'].str.replace('\W+', ' ')
data['cleaned'] = data['cleaned'].str.replace('\d+', '')
data
# Out:
#                                                     text  target  \
# 0      \n\nI am sure some bashers of Pens fans are pr...      10
# 1      My brother is in the market for a high-perform...       3
# 2      \n\n\n\n\tFinally you said what you dream abou...      17
# 3      \nThink!\n\nIt's the SCSI card doing the DMA t...       3
# 4      1)    I have an old Jasmine drive which I cann...       4
# 5      \n\nBack in high school I worked as a lab assi...      12
# 6      \n\nAE is in Dallas...try 214/241-6060 or 214/...       4
# 7      \n[stuff deleted]\n\nOk, here's the solution t...      10
# 8      \n\n\nYeah, it's the second one.  And I believ...      10
# 9      \nIf a Christian means someone who believes in...      19
# 10     the blood of the lamb.\n\nThis will be a hard ...      19
# 11      >say they have a "history of untrustworthy be...      11
# 12     930418\n\nDo what thou wilt shall be the whole...      19
# 13      How about Kirlian imaging ? I believe the FAQ...      13
# 14     \n\n\tThere is no notion of heliocentric, or e...       0
# 15     In the following report: _Turkey Eyes Regional...      17
# 16     Many thanks to those who replied to my appeal ...      12
# 17     .........\nI, some years ago, almost became a ...      12
# 18     \nThe Supreme Court seems to disagree with you...      11
# 19     \ned>1.  All of us that argue about gyroscopes...       8
# 20     : \n: I am considering buying a 1993 Chevy or ...       7
# 21     \nSorry, that's a feature.  The ICCCM specifie...       5
# 22     I don't have nor Imagine nor Real 3d, but as o...       1
# 23     \nI've only ever done it in an automatic. I wa...       8
# 24     I don't know the exact coverage in the states....      10
# 25     AW&ST  had a brief blurb on a Manned Lunar Exp...      14
# 26     \n\nThis was reported in Canadian papers Thurs...      16
# 27     Using the VMODE command, all you need to do is...       1
# 28     CAD Setup For Sale:\n\nG486PLB Local Bus Mothe...       6
# 29     [ . . .]\n\nI am a relativist who would like t...       0
# ...                                                  ...     ...
# 18816  \n\nHow about:\n\n\tThe Holocaust\n\tThe Spani...      15
# 18817  \nWhatever happened to uwm? Is it still availa...       5
# 18818  \n\n\nI'm sure there are many people who work ...       0
# 18819  \nYou'd have to purify the river water first. ...      13
# 18820  A new alternative to Scouting for those "unacc...       0
# 18821  {rest deleted}\n\nCan the Father possibly not ...      15
# 18822  \n\nThe lengthy article you quote doesn't impl...      17
# 18823  I have the local bus card also, and don't have...       2
# 18824  \nYou have to do the same sorts of things that...       5
# 18825  \n\n\n\n\tI think the Manta is the European na...       7
# 18826  \n\n\n\n    Apple has really confused people w...       4
# 18827  On 21 Apr 93 00:07:20 GMT, Theodore A. Kaldis ...      18
# 18828   \n \n Well, I'm a Wings fan and I think the F...      10
# 18829  I never thought I'd contribute to a Gateway th...       3
# 18830                              \n\n\n\n\n   Anaheim.       9
# 18831  Hello,\n\n    I am having a small problem with...       3
# 18832  \nI am asking you to believe in things not vis...      15
# 18833  I have an Alesis HR-16 drum machine for sale. ...       6
# 18834  \nProbably keep quiet and take it, lest they g...      11
# 18835  \nThey've been out of busines for years.\n\n\n...      12
# 18836  \n\nThere were a great many Germans, Poles and...      17
# 18837  \nAnd won't they have to change their name to ...      10
# 18838     [snip]\n   In the first place the death of ...      17
# 18839  \n[bible verses ag./ used ag. homosexuality de...      15
# 18840  Hi to all.\n\nSince all of you could also be a...       6
# 18841  DN> From: nyeda@cnsvax.uwec.edu (David Nye)\nD...      13
# 18842  \nNot in isolated ground recepticles (usually ...      12
# 18843  I just installed a DX2-66 CPU in a clone mothe...       3
# 18844  \nWouldn't this require a hyper-sphere.  In 3-...       1
# 18845  After a tip from Gary Crum (crum@fcom.cc.utah....       7
#
#                                                  cleaned
# 0       i am sure some bashers of pens fans are prett...
# 1      my brother is in the market for a high perform...
# 2       finally you said what you dream about mediter...
# 3       think it s the scsi card doing the dma transf...
# 4       i have an old jasmine drive which i cannot us...
# 5       back in high school i worked as a lab assista...
# 6       ae is in dallas try    or    tech support may...
# 7       stuff deleted ok here s the solution to your ...
# 8       yeah it s the second one and i believe that p...
# 9       if a christian means someone who believes in ...
# 10     the blood of the lamb this will be a hard task...
# 11      say they have a history of untrustworthy beha...
# 12      do what thou wilt shall be the whole of the l...
# 13      how about kirlian imaging i believe the faq f...
# 14      there is no notion of heliocentric or even ga...
# 15     in the following report _turkey eyes regional ...
# 16     many thanks to those who replied to my appeal ...
# 17      i some years ago almost became a victim of th...
# 18      the supreme court seems to disagree with you ...
# 19      ed  all of us that argue about gyroscopes etc...
# 20      i am considering buying a  chevy or gmc x ful...
# 21      sorry that s a feature the icccm specifies ho...
# 22     i don t have nor imagine nor real d but as old...
# 23      i ve only ever done it in an automatic i was ...
# 24     i don t know the exact coverage in the states ...
# 25     aw st had a brief blurb on a manned lunar expl...
# 26      this was reported in canadian papers thursday...
# 27     using the vmode command all you need to do is ...
# 28     cad setup for sale gplb local bus motherboard ...
# 29      i am a relativist who would like to answer yo...
# ...                                                  ...
# 18816   how about the holocaust the spanish inquisiti...
# 18817   whatever happened to uwm is it still availabl...
# 18818   i m sure there are many people who work with ...
# 18819   you d have to purify the river water first i ...
# 18820  a new alternative to scouting for those unacce...
# 18821   rest deleted can the father possibly not hear...
# 18822   the lengthy article you quote doesn t imply t...
# 18823  i have the local bus card also and don t have ...
# 18824   you have to do the same sorts of things that ...
# 18825   i think the manta is the european name for th...
# 18826   apple has really confused people with this wh...
# 18827  on  apr     gmt theodore a kaldis observed bec...
# 18828   well i m a wings fan and i think the first th...
# 18829  i never thought i d contribute to a gateway th...
# 18830                                           anaheim
# 18831  hello i am having a small problem with my soun...
# 18832   i am asking you to believe in things not visi...
# 18833  i have an alesis hr  drum machine for sale it ...
# 18834   probably keep quiet and take it lest they get...
# 18835   they ve been out of busines for years not any...
# 18836   there were a great many germans poles and oth...
# 18837   and won t they have to change their name to t...
# 18838   snip in the first place the death of three so...
# 18839   bible verses ag used ag homosexuality deleted...
# 18840  hi to all since all of you could also be a sel...
# 18841  dn from nyeda cnsvax uwec edu david nye dn a n...
# 18842   not in isolated ground recepticles usually an...
# 18843  i just installed a dx  cpu in a clone motherbo...
# 18844   wouldn t this require a hyper sphere in  spac...
# 18845  after a tip from gary crum crum fcom cc utah e...
#
# [18846 rows x 3 columns]

# %%
# Removing Stop Words
import nltk
from nltk.corpus import stopwords
#nltk.download('stopwords')
stop = stopwords.words('english')
stop = set(stop)
data['cleaned'].apply(lambda x: [item for item in x if item not in stop])
data
# Out:
#                                                     text  target  \
# 0      \n\nI am sure some bashers of Pens fans are pr...      10
# 1      My brother is in the market for a high-perform...       3
# 2      \n\n\n\n\tFinally you said what you dream abou...      17
# 3      \nThink!\n\nIt's the SCSI card doing the DMA t...       3
# 4      1)    I have an old Jasmine drive which I cann...       4
# 5      \n\nBack in high school I worked as a lab assi...      12
# 6      \n\nAE is in Dallas...try 214/241-6060 or 214/...       4
# 7      \n[stuff deleted]\n\nOk, here's the solution t...      10
# 8      \n\n\nYeah, it's the second one.  And I believ...      10
# 9      \nIf a Christian means someone who believes in...      19
# 10     the blood of the lamb.\n\nThis will be a hard ...      19
# 11      >say they have a "history of untrustworthy be...      11
# 12     930418\n\nDo what thou wilt shall be the whole...      19
# 13      How about Kirlian imaging ? I believe the FAQ...      13
# 14     \n\n\tThere is no notion of heliocentric, or e...       0
# 15     In the following report: _Turkey Eyes Regional...      17
# 16     Many thanks to those who replied to my appeal ...      12
# 17     .........\nI, some years ago, almost became a ...      12
# 18     \nThe Supreme Court seems to disagree with you...      11
# 19     \ned>1.  All of us that argue about gyroscopes...       8
# 20     : \n: I am considering buying a 1993 Chevy or ...       7
# 21     \nSorry, that's a feature.  The ICCCM specifie...       5
# 22     I don't have nor Imagine nor Real 3d, but as o...       1
# 23     \nI've only ever done it in an automatic. I wa...       8
# 24     I don't know the exact coverage in the states....      10
# 25     AW&ST  had a brief blurb on a Manned Lunar Exp...      14
# 26     \n\nThis was reported in Canadian papers Thurs...      16
# 27     Using the VMODE command, all you need to do is...       1
# 28     CAD Setup For Sale:\n\nG486PLB Local Bus Mothe...       6
# 29     [ . . .]\n\nI am a relativist who would like t...       0
# ...                                                  ...     ...
# 18816  \n\nHow about:\n\n\tThe Holocaust\n\tThe Spani...      15
# 18817  \nWhatever happened to uwm? Is it still availa...       5
# 18818  \n\n\nI'm sure there are many people who work ...       0
# 18819  \nYou'd have to purify the river water first. ...      13
# 18820  A new alternative to Scouting for those "unacc...       0
# 18821  {rest deleted}\n\nCan the Father possibly not ...      15
# 18822  \n\nThe lengthy article you quote doesn't impl...      17
# 18823  I have the local bus card also, and don't have...       2
# 18824  \nYou have to do the same sorts of things that...       5
# 18825  \n\n\n\n\tI think the Manta is the European na...       7
# 18826  \n\n\n\n    Apple has really confused people w...       4
# 18827  On 21 Apr 93 00:07:20 GMT, Theodore A. Kaldis ...      18
# 18828   \n \n Well, I'm a Wings fan and I think the F...      10
# 18829  I never thought I'd contribute to a Gateway th...       3
# 18830                              \n\n\n\n\n   Anaheim.       9
# 18831  Hello,\n\n    I am having a small problem with...       3
# 18832  \nI am asking you to believe in things not vis...      15
# 18833  I have an Alesis HR-16 drum machine for sale. ...       6
# 18834  \nProbably keep quiet and take it, lest they g...      11
# 18835  \nThey've been out of busines for years.\n\n\n...      12
# 18836  \n\nThere were a great many Germans, Poles and...      17
# 18837  \nAnd won't they have to change their name to ...      10
# 18838     [snip]\n   In the first place the death of ...      17
# 18839  \n[bible verses ag./ used ag. homosexuality de...      15
# 18840  Hi to all.\n\nSince all of you could also be a...       6
# 18841  DN> From: nyeda@cnsvax.uwec.edu (David Nye)\nD...      13
# 18842  \nNot in isolated ground recepticles (usually ...      12
# 18843  I just installed a DX2-66 CPU in a clone mothe...       3
# 18844  \nWouldn't this require a hyper-sphere.  In 3-...       1
# 18845  After a tip from Gary Crum (crum@fcom.cc.utah....       7
#
#                                                  cleaned
# 0       i am sure some bashers of pens fans are prett...
# 1      my brother is in the market for a high perform...
# 2       finally you said what you dream about mediter...
# 3       think it s the scsi card doing the dma transf...
# 4       i have an old jasmine drive which i cannot us...
# 5       back in high school i worked as a lab assista...
# 6       ae is in dallas try    or    tech support may...
# 7       stuff deleted ok here s the solution to your ...
# 8       yeah it s the second one and i believe that p...
# 9       if a christian means someone who believes in ...
# 10     the blood of the lamb this will be a hard task...
# 11      say they have a history of untrustworthy beha...
# 12      do what thou wilt shall be the whole of the l...
# 13      how about kirlian imaging i believe the faq f...
# 14      there is no notion of heliocentric or even ga...
# 15     in the following report _turkey eyes regional ...
# 16     many thanks to those who replied to my appeal ...
# 17      i some years ago almost became a victim of th...
# 18      the supreme court seems to disagree with you ...
# 19      ed  all of us that argue about gyroscopes etc...
# 20      i am considering buying a  chevy or gmc x ful...
# 21      sorry that s a feature the icccm specifies ho...
# 22     i don t have nor imagine nor real d but as old...
# 23      i ve only ever done it in an automatic i was ...
# 24     i don t know the exact coverage in the states ...
# 25     aw st had a brief blurb on a manned lunar expl...
# 26      this was reported in canadian papers thursday...
# 27     using the vmode command all you need to do is ...
# 28     cad setup for sale gplb local bus motherboard ...
# 29      i am a relativist who would like to answer yo...
# ...                                                  ...
# 18816   how about the holocaust the spanish inquisiti...
# 18817   whatever happened to uwm is it still availabl...
# 18818   i m sure there are many people who work with ...
# 18819   you d have to purify the river water first i ...
# 18820  a new alternative to scouting for those unacce...
# 18821   rest deleted can the father possibly not hear...
# 18822   the lengthy article you quote doesn t imply t...
# 18823  i have the local bus card also and don t have ...
# 18824   you have to do the same sorts of things that ...
# 18825   i think the manta is the european name for th...
# 18826   apple has really confused people with this wh...
# 18827  on  apr     gmt theodore a kaldis observed bec...
# 18828   well i m a wings fan and i think the first th...
# 18829  i never thought i d contribute to a gateway th...
# 18830                                           anaheim
# 18831  hello i am having a small problem with my soun...
# 18832   i am asking you to believe in things not visi...
# 18833  i have an alesis hr  drum machine for sale it ...
# 18834   probably keep quiet and take it lest they get...
# 18835   they ve been out of busines for years not any...
# 18836   there were a great many germans poles and oth...
# 18837   and won t they have to change their name to t...
# 18838   snip in the first place the death of three so...
# 18839   bible verses ag used ag homosexuality deleted...
# 18840  hi to all since all of you could also be a sel...
# 18841  dn from nyeda cnsvax uwec edu david nye dn a n...
# 18842   not in isolated ground recepticles usually an...
# 18843  i just installed a dx  cpu in a clone motherbo...
# 18844   wouldn t this require a hyper sphere in  spac...
# 18845  after a tip from gary crum crum fcom cc utah e...
#
# [18846 rows x 3 columns]

# %%
# from nltk.stem import PorterStemmer

# def stem_sentences(sentence):
#     porter_stemmer = PorterStemmer()
#     tokens = sentence.split()
#     stemmed_tokens = [porter_stemmer.stem(token) for token in tokens]
#     return ' '.join(stemmed_tokens)

# %%
# data['text'] = data['text'].apply(stem_sentences)
# data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data['cleaned'], data['target'], train_size=0.8,test_size=0.2)
x_train
# Out:
# 5371      hams can legally run up to  watts it is very ...
# 17908     because i m a guy and most of my pillions are...
# 6820      didn t your operating system come with x sysv...
# 12806     oh my god my spelling and grammer suck i gues...
# 14382    l jb  ron what do you consider to be proper ch...
# 1842                       what s your favorite body part
# 1482     does anyone on this group use this program it ...
# 14974     open up one of the airbag control boxes they ...
# 17931    i ve had similar problems downloading using wi...
# 5812     well i m amazed at how successful this exercis...
# 18490    i assume that can only be guessed at by the as...
# 3849      do you have a better e mail address mr lurie ...
# 614       both christians and non christians laugh at t...
# 10150       where did that idea come from it s news to me
# 15077    the latest israeli proposal first proposed in ...
# 14205     the joystick reads in anolog values through a...
# 8159                     nanao call     ask for a catalog
# 4296      well yes and no the _image_ can t be on the s...
# 4446     i have a sun   that has a mono framebuffer bwt...
# 12938    for sale sherwood am fm stereo reciever  memor...
# 8278
# 12157    as the title says i would like to sell my star...
# 1244      imho the original poster has no business soli...
# 3986      fine libertarians and anarchists are not alon...
# 2567     brings up the issue of how the escrow agent wi...
# 18670     one thing to recall putting a satellite as hi...
# 1715      hi everybody i guess my subject has said it a...
# 8033     i really don t know how you can possibly maint...
# 9902      on tuesday when it was raining in chicago esp...
# 6224     could someone please tell me if a   decoder is...
#                                ...
# 8957      uh no these burst detectors are just that bur...
# 6086     call for papers the internet society symposium...
# 12763    ekdfc ttacs ttu edu david coons the rules say ...
# 16386    he dimmagio s henderson s stat s are probably ...
# 12767     i was very lucky i found a jacket i liked tha...
# 16816     really no gravity is an inherent system you d...
# 9519     ik nntp posting host elm ik i know it sounds s...
# 8909      but maybe his wife was i don t claim to know ...
# 1302     i would like to apologize for the typos in the...
# 6300     i am selling my sportster to make room for a n...
# 7063                                  eric h taylor writes
# 1707      the other jewish hof er is rod carew who conv...
# 18757     jesus also recognized other holy days like th...
# 11977     note that the laws that don t agree with you ...
# 1198      ah so you finally found a use for that super ...
# 308       no no no it s a squid keep the tradition aliv...
# 18611    here are the standings after game  of each of ...
# 451       point  i m beginning to see that part of the ...
# 7839       you haven t shown any disproportionate invol...
# 3430      what evidence are you aware of what was repor...
# 10523    alexis perry asked if low blood potassium coul...
# 6391     does anyone know the pin outs for the c eprom ...
# 8868      ah but why can some technically hip macslinge...
# 12507    this may be an faq but i dont know where to ge...
# 5210     as i was created in the image of gaea therefor...
# 4537      not necessarily as shai points out political ...
# 2170      does anyone know of an x based terminal emula...
# 13641     on these counts the apocrapha falls short of ...
# 18017    hi anybody interested in buying my labtec spea...
# 16355    hi all i m looking for some info regarding an ...
# Name: cleaned, Length: 15076, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()
x_train_counts = count_vect.fit_transform(x_train)
x_test_counts = count_vect.transform(x_test)
x_train_counts.shape
# Out:
# (15076, 92329)

# %%
x_test_counts.shape
# Out:
# (3770, 92329)

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer(max_features=2000)
x_train_counts = count_vect.fit_transform(x_train)
x_test_counts = count_vect.transform(x_test)
x_train_counts = x_train_counts.toarray()

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer()
x_train_tfidf = tfidf_transformer.fit_transform(x_train_counts)
x_test_tfidf = tfidf_transformer.transform(x_test_counts)

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC(max_iter=2000).fit(x_train_counts, y_train)
predicted = clf.predict(x_test_counts)
np.mean(predicted == y_test)
# Out:
# C:\Users\hicks\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 0.5363395225464191

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC(max_iter=2000).fit(x_train_tfidf, y_train)
predicted = clf.predict(x_test_tfidf)
np.mean(predicted == y_test)
# Out:
# 0.6267904509283819

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, predicted, target_names=target_names))
# Out:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.50      0.49      0.50       150
#            comp.graphics       0.56      0.55      0.56       199
#  comp.os.ms-windows.misc       0.66      0.60      0.63       220
# comp.sys.ibm.pc.hardware       0.61      0.58      0.60       204
#    comp.sys.mac.hardware       0.57      0.60      0.58       176
#           comp.windows.x       0.70      0.71      0.70       187
#             misc.forsale       0.77      0.73      0.75       199
#                rec.autos       0.43      0.67      0.53       206
#          rec.motorcycles       0.65      0.60      0.62       218
#       rec.sport.baseball       0.67      0.66      0.66       201
#         rec.sport.hockey       0.74      0.74      0.74       187
#                sci.crypt       0.72      0.75      0.73       203
#          sci.electronics       0.51      0.52      0.51       185
#                  sci.med       0.68      0.69      0.69       203
#                sci.space       0.72      0.64      0.68       184
#   soc.religion.christian       0.65      0.72      0.69       196
#       talk.politics.guns       0.63      0.64      0.63       182
#    talk.politics.mideast       0.82      0.73      0.77       197
#       talk.politics.misc       0.52      0.50      0.51       146
#       talk.religion.misc       0.32      0.19      0.24       127
#
#                micro avg       0.63      0.63      0.63      3770
#                macro avg       0.62      0.62      0.62      3770
#             weighted avg       0.63      0.63      0.63      3770

# %%
tfidf_transformer = TfidfTransformer()
count_vect = CountVectorizer(max_features=2000)

x_counts = count_vect.fit_transform(data['cleaned'])
x_tfidf = tfidf_transformer.fit_transform(x_counts)

# %%
#initialize kmeans, choose random k points in the original array of of points
def init_kmeans(x,k):
    return [random.choice(x) for i in range(k)]

#this finds the minimum distance 
def find_min(z,x_cur):
    distances = []
    for z_i in range(len(z)):
        distances.append(np.linalg.norm(x_cur - z[z_i]))
    return distances.index(min(distances))
def plot_jclust(j_clust_a):
    for j_clust in j_clust_a:
        plt.plot(j_clust)
    plt.xlim(0, 25)
    plt.xlabel('Iteration')
    plt.ylabel('$J^{clust}$')
    plt.show

# %%
def kmeans(x,k):
    #Initializing K-means
    c = []
    j_clust = []  
    z = init_kmeans(x,k)
    
    while True:
        groups = [[] for new_list in range(k)]
        groups_i = [[] for new_list in range(k)]
        #Reassigning groups according to previously calculated representatives
        for x_i in range(len(x)):
            center = find_min(z,x[x_i])
            c.append(center)
            groups[center].append(x[x_i])
            groups_i[center].append(x_i)

            

        #Finding new representatives from groups
        for z_i in range(len(z)):
            z[z_i] = np.mean(groups[z_i], axis=0)

        #Calculating j_clust
        j = []
        for z_i in range(len(z)):
            for group_i, group_cur in enumerate(groups[z_i]):
                j.append(np.linalg.norm(group_cur - z[z_i])**2) 
        j_clust.append(np.sum(j)/len(x))

        #End conditions for K-means
        #Comparing j_clust to save computation time (with unchanging z_i, must have the same j_clust)
        if len(j_clust) == 0 or len(j_clust) == 1:
            continue
        #End Kmeans when j_clust is about equal
        if (round(j_clust[-1],3) == round(j_clust[-2],3)):
            break
    return z,j_clust,groups

# %%
z, j_clust, groups = kmeans(x_tfidf.toarray(), 10)

# %%
from sklearn.cluster import KMeans
km = KMeans(n_clusters=20, init='k-means++', max_iter=100, n_init=1)
km.fit(x_tfidf.toarray())
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=100,
#     n_clusters=20, n_init=1, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
np.find(km.labels_ == 10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-ae6cb54bc6b3> in <module>()
# ----> 1 np.find(km.labels_ == 10)
#
# AttributeError: module 'numpy' has no attribute 'find'
